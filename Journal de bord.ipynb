# %% [markdown]
# # 📘 Journal de bord — Analyse du marché Steam (2014–2024)
# Najoua Nouioura – SIEF – Novembre / Décembre 2025
#
# ---
#
# ## 🗓️ 4 novembre — **Jour 1 : Exploration & Choix du dataset**
#
# ### **1. Recherche et sélection de la base de données**
# - Exploration de plusieurs datasets publics (notamment Kaggle).
# - Objectif : identifier une base riche permettant d’analyser 10 ans de tendances Steam.
# - Sélection finale : **Steam Games Dataset** (Kaggle).
# - Contenu pertinent :
#   - métadonnées des jeux (nom, date, plateforme…)
#   - avis positifs / négatifs
#   - genres et tags
#   - prix et compatibilités Windows / Mac / Linux
#
# ### **2. Vérification de la qualité des données**
# - Inspection manuelle et programmatique.
# - Analyse :
#   - valeurs manquantes
#   - incohérences sur les dates
#   - genres stockés comme chaînes JSON
#   - doublons possibles
#   - colonnes inutiles pour l’analyse
#
# ### **3. Identification des problèmes**
# - Genres mal formatés (`"['Action','Adventure']"`).
# - Valeurs manquantes dans `Developer`, `Publisher`, `Price`.
# - Présence de jeux NSFW.
# - Présence de jeux très peu populaires (< 50 avis), risquant de biaiser l’analyse.
#
# ➡️ Résultat : une liste claire d'opérations à effectuer pour obtenir un dataset exploitable.
#
# ---
#
# ## 🗓️ 7 novembre — **Jour 2 : Analyse exploratoire + Définition de la problématique**
#
# ### **1. Nettoyage dans un notebook**
# Opérations réalisées :
# - conversion des dates
# - ajout de colonnes dérivées :
#   - `Release_year`
#   - `Total_reviews`
#   - `Ratio_Positive`
# - parsing correct des genres → création de `Genres_list`
# - suppression des jeux NSFW
# - suppression des jeux très peu populaires
# - filtrage des titres anormaux (trop longs, tout en majuscules)
# - harmonisation des types numériques
# - Suppression des colonnes inutiles dans `games_clean.csv`
#
# ### **2. Analyse exploratoire (EDA)**
# Premiers graphiques :
# - évolution du nombre de sorties par année
# - distribution des prix
# - répartition des genres
# - corrélation popularité × qualité
#
# ### **3. Définition de la problématique**
# À partir des observations :
#
# > **Quels sont les facteurs qui déterminent le succès d’un jeu sur Steam,
# et comment identifier les genres les plus prometteurs entre 2014 et 2024 ?**
#
# ➡️ Cette problématique a guidé toute la suite du projet.
#
# ---
#
# ## 🗓️ 17 novembre — **Jour 3 : Développement complet de l'application Streamlit**
#
# ### **1. Architecture de l’application**
# Création de différentes pages :
# - Page d’accueil stylisée
# - Marché global
# - Jeux populaires
# - Genres & Stratégies
# - Synthèse & Conclusions
# - Moteur de recommandations
#
# ### **2. Intégration du dataset nettoyé**
# - Chargement optimisé avec cache (`st.cache_data`)
# - Version allégée du CSV (colonnes inutiles supprimées)
# - Gestion robuste des listes, NA et conversions
#
# ### **3. Création des visualisations**
# Graphiques produits :
# - histogrammes (prix)
# - courbes temporelles (évolution des sorties, croissance des genres)
# - scatterplots (popularité × qualité)
# - carte stratégique (qualité × popularité × volume)
#
# ### **4. Moteur de recommandation**
# Développement :
# - fonction de similarité basée sur :
#   - chevauchement des genres
#   - proximité qualitative (ratio)
#   - proximité populaire (log des avis)
# - filtrage par catégories dominantes
# - retour des 5 jeux les plus proches
#
#
# ➡️ À cette date, l'application était **structurellement terminée et fonctionnelle**.
#
# ---
#
# ## 🗓️ 1er décembre — **Finalisation & Déploiement**
#
# ### **1. Travail esthétique**
# - CSS personnalisé (bleu/violet type Steam)
# - effet technologique sombre
# - sections structurées
# - navigation intuitive entre les pages
#
# ### **2. Optimisations finales**
# - Correction du bug des genres vides
# - Nettoyage des graphiques
# - Ajustements visuels (marges, couleurs)
#
# ### **3. Dépôt GitHub**
# - organisation du projet :
# /streamlit_app
# /data
# /pages
# app.py
# requirements.txt
#
# ### **4. Déploiement Streamlit Cloud**
# - configuration du repository
# - tests sur navigateur
# - correction des erreurs de chargement des gros fichiers
# - version finale opérationnelle
#
# ---
#
# # ✅ Résumé global
#
# | Date | Étape | Résultat |
# |------|--------|----------|
# | **4 nov.** | Exploration & sélection | Dataset choisi et analysé |
# | **7 nov.** | Nettoyage + EDA + problématique | Dataset propre + analyses préliminaires |
# | **17 nov.** | Construction Streamlit | App complète et fonctionnelle |
# | **1 déc.** | Optimisation + Déploiement | Version finale publique et présentable |
#
# ---
